# %% [markdown]
# # SED plots.
# ## This is the notebook to generate the SED plot from Fermi-LAT flux upper limits.

# %%
import numpy as np
import os
from fermipy.gtanalysis import GTAnalysis
from fermipy.plotting import ROIPlotter, SEDPlotter
import matplotlib.pyplot as plt
import matplotlib
matplotlib.interactive(True)

# %%
data1 = np.load('source2_sed_test.npy',allow_pickle=True).flat[0]
data2 = np.load('source3_sed_test.npy',allow_pickle=True).flat[0]
data3 = np.load('source8_sed_test.npy',allow_pickle=True).flat[0]
data4 = np.load('source11_sed_test.npy',allow_pickle=True).flat[0]
data5 = np.load('source16_sed_test.npy',allow_pickle=True).flat[0]
data6 = np.load('source17_sed_test.npy',allow_pickle=True).flat[0]
data7 = np.load('source20_sed_test.npy',allow_pickle=True).flat[0]
data8 = np.load('source12_sed_test.npy',allow_pickle=True).flat[0]
data9 = np.load('source13_sed_test.npy',allow_pickle=True).flat[0]

# %%
fig = plt.figure(figsize=(24,24))
ylim=[1E-8,1E-5]
plt.rcParams.update({'font.size': 24})
fig.add_subplot(3,3,1)
SEDPlotter(data1).plot()
plt.gca().set_ylim(ylim)
plt.title('Source 1', y=0.9, pad=-14)
plt.xlabel('')
plt.ylabel('$\mathrm{E^{2}\,d\phi/dE}$ $\mathrm{(MeV\,cm^{-2}\,s^{-1})}$')
#plt.legend(loc='upper left',"Source 1")
# Out:
# Text(0, 0.5, '$\\mathrm{E^{2}\\,d\\phi/dE}$ $\\mathrm{(MeV\\,cm^{-2}\\,s^{-1})}$')

# %%
fig.add_subplot(3,3,2)
SEDPlotter(data2).plot()
plt.gca().set_ylim(ylim)
plt.title('Source 2', y=0.9, pad=-14)
plt.xlabel('')
plt.ylabel('')
#plt.legend(loc='upper left')
# Out:
# Text(0, 0.5, '')

# %%
fig.add_subplot(3,3,3)
SEDPlotter(data3).plot()
plt.gca().set_ylim(ylim)
plt.title('Source 3', y=0.9, pad=-14)
plt.xlabel('')
plt.ylabel('')
#plt.legend(loc='upper left')
# Out:
# Text(0, 0.5, '')

# %%
fig.add_subplot(3,3,4)
SEDPlotter(data4).plot()
plt.gca().set_ylim(ylim)
plt.title('Source 4', y=0.9, pad=-14)
plt.xlabel('')
plt.ylabel('$\mathrm{E^{2}\,d\phi/dE}$ $\mathrm{(MeV\,cm^{-2}\,s^{-1})}$')
#plt.legend(loc='upper left')
# Out:
# Text(0, 0.5, '$\\mathrm{E^{2}\\,d\\phi/dE}$ $\\mathrm{(MeV\\,cm^{-2}\\,s^{-1})}$')

# %%
fig.add_subplot(3,3,5)
SEDPlotter(data5).plot()
plt.gca().set_ylim(ylim)
plt.title('Source 5', y=0.9, pad=-14)
plt.xlabel('')
plt.ylabel('')
#plt.legend(loc='upper left')
# Out:
# Text(0, 0.5, '')

# %%
fig.add_subplot(3,3,6)
SEDPlotter(data6).plot()
plt.gca().set_ylim(ylim)
plt.title('Source 6', y=0.9, pad=-14)
plt.xlabel('Energy (MeV)')
plt.ylabel('')
#plt.legend(loc='upper left')
# Out:
# Text(0, 0.5, '')

# %%
fig.add_subplot(3,3,7)
SEDPlotter(data7).plot()
plt.gca().set_ylim(ylim)
plt.title('Source 7', y=0.9, pad=-14)
plt.xlabel('Energy (MeV)')
plt.ylabel('$\mathrm{E^{2}\,d\phi/dE}$ $\mathrm{(MeV\,cm^{-2}\,s^{-1})}$')
#plt.legend(loc='upper left')
# Out:
# Text(0, 0.5, '$\\mathrm{E^{2}\\,d\\phi/dE}$ $\\mathrm{(MeV\\,cm^{-2}\\,s^{-1})}$')

# %%
fig.add_subplot(3,3,8)
SEDPlotter(data8).plot()
#plt.gca().set_ylim(ylim)
plt.title('Source 8', y=0.9, pad=-14)
plt.xlabel('Energy (MeV)')
plt.ylabel('')
#plt.legend(loc='upper left')
# Out:
# Text(0, 0.5, '')

# %%
fig.add_subplot(3,3,9)
SEDPlotter(data9).plot()
#plt.gca().set_ylim(ylim)
plt.title('Source 9', y=0.9, pad=-14)
plt.xlabel('Energy (MeV)')
plt.ylabel('')
#plt.legend(loc='upper left')
# Out:
# Text(0, 0.5, '')

# %%
#outfile = 'sed_new_source.png'
fig.savefig('sed_plot.pdf')
plt.show()
